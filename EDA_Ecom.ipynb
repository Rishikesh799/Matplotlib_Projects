# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # IMporting data sets

# %%
df_test=pd.read_csv("test.csv")

# %%
df_train=pd.read_csv("train.csv")

# %%
df_test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # Combine data sets

# %%
df=df_train.append(df_test,ignore_index=True)

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 783662  1006036  P00118942      F  26-35          15             B
# 783663  1006036  P00254642      F  26-35          15             B
# 783664  1006036  P00031842      F  26-35          15             B
# 783665  1006037  P00124742      F  46-50           1             C
# 783666  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.drop(columns=["User_ID"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %% [markdown]
# # Convert Categorical data into numerical

# %%
#GENDER 
df["Gender"]=df["Gender"].map({"F":0,"M":1})

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %% [markdown]
# #AGE

# %%
df.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Age"].value_counts()
# Out:
# 26-35    313015
# 36-45    156724
# 18-25    141953
# 46-50     65278
# 51-55     54784
# 55+       30579
# 0-17      21334
# Name: Age, dtype: int64

# %%
df["Age"]=df["Age"].map({'0-17':1, '55+':7, '26-35':3, '46-50':5, '51-55':6, '36-45':4, '18-25':2})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
#City_Ctegory

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["City_Category"]=df["City_Category"].map({'A':1, 'C':2, 'B':3})

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation  City_Category  \
# 0       P00069042       0    1          10              1
# 1       P00248942       0    1          10              1
# 2       P00087842       0    1          10              1
# 3       P00085442       0    1          10              1
# 4       P00285442       1    7          16              2
# ...           ...     ...  ...         ...            ...
# 783662  P00118942       0    3          15              3
# 783663  P00254642       0    3          15              3
# 783664  P00031842       0    3          15              3
# 783665  P00124742       0    5           1              2
# 783666  P00316642       0    5           0              3
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
#Missing values

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.388587
# Product_Category_3            69.648078
# Purchase                      29.808452
# dtype: float64

# %%
df["Product_Category_2"].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df["Product_Category_2"].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %%
#Replace missing value with mode.

# %%
x=df["Product_Category_2"].mode()[0]

# %%
x
# Out:
# 8.0

# %%
df["Product_Category_2"].fillna(x,inplace=True)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation  City_Category  \
# 0       P00069042       0    1          10              1
# 1       P00248942       0    1          10              1
# 2       P00087842       0    1          10              1
# 3       P00085442       0    1          10              1
# 4       P00285442       1    7          16              2
# ...           ...     ...  ...         ...            ...
# 783662  P00118942       0    3          15              3
# 783663  P00254642       0    3          15              3
# 783664  P00031842       0    3          15              3
# 783665  P00124742       0    5           1              2
# 783666  P00316642       0    5           0              3
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df["Product_Category_2"].isnull().sum()
# Out:
# 0

# %%
#For df["Product_Category_3"]

# %%
df["Product_Category_3"].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df["Product_Category_3"].value_counts()
# Out:
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: Product_Category_3, dtype: int64

# %%
df["Product_Category_3"].fillna(df["Product_Category_3"].mode()[0],inplace=True)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation  City_Category  \
# 0       P00069042       0    1          10              1
# 1       P00248942       0    1          10              1
# 2       P00087842       0    1          10              1
# 3       P00085442       0    1          10              1
# 4       P00285442       1    7          16              2
# ...           ...     ...  ...         ...            ...
# 783662  P00118942       0    3          15              3
# 783663  P00254642       0    3          15              3
# 783664  P00031842       0    3          15              3
# 783665  P00124742       0    5           1              2
# 783666  P00316642       0    5           0              3
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
#Stay_In_Current_City_Years

# %%
df.Stay_In_Current_City_Years.unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Stay_In_Current_City_Years"]=df["Stay_In_Current_City_Years"].str.replace("+","").astype(int)
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_19836/3391494167.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Stay_In_Current_City_Years"]=df["Stay_In_Current_City_Years"].str.replace("+","").astype(int)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation  City_Category  \
# 0       P00069042       0    1          10              1
# 1       P00248942       0    1          10              1
# 2       P00087842       0    1          10              1
# 3       P00085442       0    1          10              1
# 4       P00285442       1    7          16              2
# ...           ...     ...  ...         ...            ...
# 783662  P00118942       0    3          15              3
# 783663  P00254642       0    3          15              3
# 783664  P00031842       0    3          15              3
# 783665  P00124742       0    5           1              2
# 783666  P00316642       0    5           0              3
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# 1                                2               0                   1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   City_Category               783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  int32
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
# dtypes: float64(3), int32(1), int64(6), object(1)
# memory usage: 62.8+ MB

# %%
#Visualization

# %%
sns.pairplot(df)

# %%
#visualization of age and purchase

# %%
sns.barplot("Age","Purchase",data=df,hue="Gender")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# CONCLUSION: Purchsing of men quite high as compared to woman.

# %%
#VIsualization of purchsae with occupation

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="Occupation",y="Purchase",data=df,hue="Gender")
plt.show()

# %%
#Vicsualization of product 1,product 2,product 3 with prchase.

# %% [markdown]
# # "Product_Category_1"

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="Product_Category_1",y="Purchase",data=df)
plt.show()

# %% [markdown]
# Conclusion: In product category 1 10 no category prchase id high. And it also high as compared with other product cateogory.

# %% [markdown]
# # x="Product_Category_2"

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="Product_Category_2",y="Purchase",data=df)
plt.show()

# %%
Conclusion:Here also no 10 category is high purchase.

# %% [markdown]
# # "Product_Category_3"

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="Product_Category_3",y="Purchase",data=df)
plt.show()

# %%
Conclusion:  In product category 3 all category are same purchase but the 3 no category is quite high purchase.
