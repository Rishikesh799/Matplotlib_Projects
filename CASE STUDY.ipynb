# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Salaries.csv",low_memory=False)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # Display first 10 rows

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# # Display last 10 rows

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# # shape of our dataset

# %%
df.shape
# Out:
# (148654, 13)

# %% [markdown]
# # Getting info about our datasetlike total no of rows ,total no of columns ,data type of each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# # Check null values in our dataset

# %%
b=df.isnull().sum()

# %%
import matplotlib.pyplot as plt
plt.barh(b.index,b.values)
plt.xticks(rotation=90)
plt.ylabel("Column name",fontsize=15)
plt.xlabel("Values",fontsize=15)
plt.show()

# %%
n=df.isnull().sum()*100/len(df)

# %%
new_n=n[n>20].index

# %%
df.drop(columns=new_n,inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # drop null value present column

# %%
x=df.drop(["Notes","Status"],axis=1)

# %%
x
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # Get overall statistics of df

# %%
d=x.describe()

# %%
d
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year
# count  148654.000000  148654.000000     148654.000000  148654.000000
# mean    74327.500000   74768.321972      93692.554811    2012.522643
# std     42912.857795   50517.005274      62793.533483       1.117538
# min         1.000000    -618.130000       -618.130000    2011.000000
# 25%     37164.250000   36168.995000      44065.650000    2012.000000
# 50%     74327.500000   71426.610000      92404.090000    2013.000000
# 75%    111490.750000  105839.135000     132876.450000    2014.000000
# max    148654.000000  567595.430000     567595.430000    2014.000000

# %%
plt.bar(d.index,d.TotalPayBenefits)
plt.title("TotalPayBenefits")
plt.show()

# %%
d[["TotalPay","TotalPayBenefits"]].plot(subplots=True,sharex=False,layout=(1,2),figsize=(10,4))
plt.tight_layout()

# %%
d[["TotalPay","TotalPayBenefits"]].plot(kind="bar",subplots=True,figsize=(10,6))
plt.tight_layout()
plt.ylabel("Numbers")
plt.show()

# %% [markdown]
# # Find the occurance of the Employee Names

# %%
x["EmployeeName"].value_counts().head()
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# # Unique job title

# %%
x["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
x["JobTitle"].nunique()
# Out:
# 2159

# %% [markdown]
# # if i want total no of job titles  Custodian

# %%
x.groupby("JobTitle").get_group("Custodian")
# Out:
#             Id        EmployeeName   JobTitle   BasePay OvertimePay OtherPay  \
# 55797    55798        Jeannie Shen  Custodian  54067.84    12890.29    624.0
# 56187    56188    Vallery Williams  Custodian  51502.01         0.0  13856.0
# 56411    56412      Walfred Ferrer  Custodian   51502.1      6312.7  6585.35
# 56455    56456     Raymond J Huang  Custodian   51492.8    13319.85  1012.85
# 56597    56598          Zhen-Li Li  Custodian   51502.0    10109.67  3434.62
# ...        ...                 ...        ...       ...         ...      ...
# 148461  148462         Lian Xiu Wu  Custodian    177.81        0.00    14.23
# 148579  148580  George S Dela Pena  Custodian      0.00        0.00    54.39
# 148639  148640   Richard A Talbert  Custodian      0.00        0.00     0.00
# 148648  148649         Leon Walker  Custodian      0.00        0.00     0.00
# 148649  148650       Roy I Tillery  Custodian      0.00        0.00     0.00
#
# ...

# %%
x.groupby("JobTitle").get_group("Custodian").count()
# Out:
# Id                  2418
# EmployeeName        2418
# JobTitle            2418
# BasePay             2409
# OvertimePay         2418
# OtherPay            2418
# Benefits            2418
# TotalPay            2418
# TotalPayBenefits    2418
# Year                2418
# Agency              2418
# dtype: int64

# %%
c=df.groupby("Year").TotalPay.mean()

# %%
c
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %%
plt.plot(c.index,c.values,marker="o",color="m")
plt.title("Line plot")
plt.xlabel("Year",fontsize=15)
plt.show()

# %%
plt.scatter(df.index,df.TotalPay)
plt.title("Scatter plot")
plt.xlabel("Year",fontsize=15)
plt.show()
