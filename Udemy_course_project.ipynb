# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("udemy_courses.csv")

# %% [markdown]
# # top 10 row

# %%
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# # last 5 row

# %%
df.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# # shape

# %%
df.shape
# Out:
# (3678, 12)

# %% [markdown]
# # info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %% [markdown]
# # null values

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# # drop duplicated values

# %%
x=df[df.duplicated()].index

# %%
df.drop(x).shape
# Out:
# (3672, 12)

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %% [markdown]
# # find no of course per subject

# %%
k=df["subject"].value_counts()

# %%
k
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(k.index,k.values,marker="o")
plt.xticks(rotation=60,fontsize=10)
plt.xlabel("Subject",fontsize=15)
plt.ylabel("NO of course",fontsize=15)
plt.title("No of course VS sbject")
plt.show()

# %% [raw]
# This above graph shows subject and thier no of course of each subject.

# %% [markdown]
# # level of course

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %% [markdown]
# # how many are paid and free course

# %%
l=df["is_paid"].value_counts()

# %%
l
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
plt.bar(l.index,l.values,width=0.5,color=["b","g"])
plt.xticks(ticks=range(2),labels=["Free","Paid"])
plt.xlabel("Type of course")
plt.ylabel("NO of courses")
plt.title("Total no of course are free and paid")
plt.show()

# %% [raw]
# CONCLUSION: No of free course are less than no of paid course.

# %% [markdown]
# # which course has more lecture and its paid or free

# %%
y=df["num_lectures"].sort_values(ascending=False).head(1)

# %%
y
# Out:
# 2707    779
# Name: num_lectures, dtype: int64

# %%
df.query('num_lectures==779')[["course_title","is_paid"]]
# Out:
#                                            course_title  is_paid
# 2707  Back to School Web Development and Programming...     True

# %% [markdown]
# # course having highest subscribers

# %%
df["num_subscribers"].max()
# Out:
# 268923

# %%
df.query('num_subscribers==268923')[["course_title","is_paid"]]
# Out:
#                               course_title  is_paid
# 2827  Learn HTML5 Programming From Scratch    False

# %% [markdown]
# # level of highest subscribers

# %%
df.query('num_subscribers==268923')[["level"]]
# Out:
#            level
# 2827  All Levels

# %% [markdown]
# # popular course

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
z=df["num_subscribers"].max()

# %%
z
# Out:
# 268923

# %%
df.query('num_subscribers==268923')[["course_title"]]
# Out:
#                               course_title
# 2827  Learn HTML5 Programming From Scratch

# %% [markdown]
# # 10 most popular courses

# %%
c=df["num_subscribers"].sort_values(ascending=False).head(10).index

# %%
c
# Out:
# Int64Index([2827, 3032, 3230, 2783, 3232, 1896, 2589, 2619, 3289, 3247], dtype='int64')

# %%
b=df.loc[c]["course_title"]

# %%
b.values
# Out:
# array(['Learn HTML5 Programming From Scratch',
#        'Coding for Entrepreneurs Basic', 'The Web Developer Bootcamp',
#        'Build Your First Website in 1 Week with HTML5 and CSS3',
#        'The Complete Web Developer Course 2.0',
#        'Free Beginner Electric Guitar Lessons',
#        'Web Design for Web Developers: Build Beautiful Websites!',
#        'Learn Javascript & JQuery From Scratch',
#        'Practical PHP: Master the Basics and Code Dynamic Websites',
#        'JavaScript: Understanding the Weird Parts'], dtype=object)

# %%
plt.barh(b.values,c,color=["y"])
plt.xticks(rotation=0)
plt.xlabel("Num of Subscribers",fontsize=15)
plt.ylabel("Popular Course",fontsize=15)
plt.title("Popular course")
plt.show()

# %% [raw]
# CONCLUSION: Top 10 popular courses are show in above graph.

# %% [markdown]
# # course having max review

# %%
df["num_reviews"].max()
# Out:
# 27445

# %%
df.query('num_reviews==27445')["course_title"]
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %% [markdown]
# # python containing in course title

# %%
df["course_title"].str.contains("python",case=False).sum()
# Out:
# 29

# %%
df[df["course_title"].str.contains("python",case=False)]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
df[df["course_title"].str.contains("python",case=False)].sort_values(by='num_subscribers',ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...
